# %% [markdown]
# # EDA

# %% [markdown]
# ## Motivation

# %% [markdown]
# To set up a biorefinery in a region, an **understanding of the region’s current and future biomass produce** will be required.
#
# This biomass needs to be:
# 1. Collected and transported to intermediate depots for **de-moisturisation and densification into pellets**.
# 2. The pellets will then need to be **transported to the biorefinery** for conversion to biofuel.
#
# ![bioprocess](../../img/Harvesting_Pellets_Bioref.png)
#
# This incurs high cost of feedstock transportation and associated GHG emissions, which will need to be minimised too. The value it generates lies not only in contribution to the global energy transition, but also benefits farmers as a sustainable source of
# income.

# %% [markdown]
# ## Problem Goal

# %% [markdown]
# Using the provided data, you are required to forecast biomass availability as well as design the optimal supply chain for the years 2018 and 2019, following the objective and constraints given in the subsequent sections.
#
# 1. Biomass Forecast (biomass_forecast)
# 2. Set Optimal Location for:
# - Depots (depot_location): Where the biomass is pelletized (i.e. packed)
# - Refineries (refinery_location): Where the pellets are used for energy generation.
# 3. The supplies for
# - Depots (biomass_demand_supply)
# - Refineries (pellet_demand_supply)

# %% [markdown]
# ## Objective Functions and Constraints

# %% [markdown]
# $$
# Cost_{transport} = \left(\sum_{i, j}D_{i,j}Biomass_{i,j}\right) + \left(\sum_{j, k}D_{j, k}Pellet_{j, k}\right)
# $$
#
# $$
# Cost_{forecast} = MAE\left(Biomass_{i, j}, Biomass_{i, j}^{forecast}\right)
# $$
#
# $$
# Cost_{underuse} = \sum_{i, j}\left(Cap_{depot} - \sum_{i,j}Biomass_{i, j}\right) + \sum_{j, k}\left(Cap_{refinery} - \sum_{j, k}Biomass_{j, k}\right)
# $$

# %% [markdown]
# $$
# Cost = 0.001Cost_{transport} + Cost_{forecast} + Cost_{underuse}
# $$

# %% [markdown]
# 1. All values (forecasted biomass, biomass demand-supply, pellet demand-supply) must be
# greater than or equal to zero.
#
# $$
# Biomass_{i}^{forecast} >= 0,\quad biomass\_demand\_supply >= 0,\quad pellet\_demand\_supply >=0
# $$
#
# 2. The amount of biomass procured for processing from each harvesting site ′𝑖′ must be less than or equal to that site’s forecasted biomass.
# $$
# \sum_{j}Biomass_{i, j} <= Biomass_{i}^{forecast}
# $$
#
# 3. Total biomass reaching each preprocessing depot ′𝑗′ must be less than or equal to its yearly processing capacity (20,000).
# $$
# \sum_{i}Biomass_{i, j} <= Cap_{depot}^j
# $$
# 4. Total pellets reaching each refinery ′𝑘′ must be less than or equal to its yearly processing capacity (100,000).
# $$
# \sum_{j}Pellet_{j, k} <= Cap_{refinery}^k
# $$
# 5. Number of depots should be less than or equal to 25.
# $$
# j<=25
# $$
# 6. Number of refineries should be less than or equal to 5.
# $$
# k<=5
# $$
# 7. At least 80% of the total forecasted biomass must be processed by refineries each year.
#
# $$
# \sum_{j, k}Pellet_{j, k, year} >= 0.8\sum_{i, j}Biomass^{forecast}_{i, j, year}
# $$
#
# 8. Total amount of biomass entering each preprocessing depot is equal to the total amount of
# pellets exiting that depot (within tolerance limit of 1e-03).
# $$\sum_{i}Biomass_{i, j} = \sum_{k}Pellet_{j, k}$$

# %% [markdown]
# # Data

# %%
import pandas as pd
import numpy as np

# %%
cap_depot = 20_000
cap_ref = 100_000
n_depots = 25
n_ref = 5
min_proc_bio_rate = 0.8

# %% [markdown]
# ## Biomass History

# %% [markdown]
# A time-series of biomass availability in the state of Gujarat from year
# 2010 to 2017. We have considered arable land as a map of 2418 equisized grid blocks
# (harvesting sites). For ease of use, we have flattened the map and provided location index,
# latitude, longitude, and year wise biomass availability for each Harvesting Site

# %%
df_bio = pd.read_csv('../../data/Biomass_History.csv')
df_bio.head()
# Out:
#    Index  Latitude  Longitude       2010       2011       2012       2013  \
# 0      0  24.66818   71.33144   8.475744   8.868568   9.202181   6.023070
# 1      1  24.66818   71.41106  24.029778  28.551348  25.866415  21.634459
# 2      2  24.66818   71.49069  44.831635  66.111168  56.982258  53.003735
# 3      3  24.66818   71.57031  59.974419  80.821304  78.956543  63.160561
# 4      4  24.66818   71.64994  14.653370  19.327524  21.928144  17.899586
#
#         2014       2015       2016        2017
# 0  10.788374   6.647325   7.387925    5.180296
# 1  34.419411  27.361908  40.431847   42.126946
# 2  70.917908  42.517117  59.181629   73.203232
# 3  93.513924  70.203171  74.536720  101.067352
# 4  19.534035  19.165791  16.531315   26.086885

# %% [markdown]
# ## Distances Matrix

# %% [markdown]
# The travel distance from source grid block to destination grid block,
# provided as a 2418 x 2418 matrix. Note that this is not a symmetric matrix due to U-turns, oneways etc. that may result into different distances for ‘to’ and ‘from’ journey between source
# and destination.

# %%
df_dist = pd.read_csv("../../data/Distance_Matrix.csv")
df_dist.head()
# Out:
#    Unnamed: 0        0        1        2        3        4        5        6  \
# 0           0   0.0000  11.3769  20.4557  38.1227  45.3810  54.9915  78.6108
# 1           1  11.3769   0.0000   9.0788  28.9141  36.1724  45.7829  69.4022
# 2           2  20.4557   9.0788   0.0000  22.3791  29.6374  39.2478  62.8671
# 3           3  38.1227  28.9141  22.3791   0.0000  11.8343  23.5413  41.8396
# 4           4  45.3810  36.1724  29.6374  11.8343   0.0000  11.7070  24.3986
#
#           7         8    ...         2408      2409      2410      2411  \
# 0  118.6750  102.6639    ...     683.8771  687.6310  697.3246  669.3962
# 1   78.2329   93.4553    ...     681.6295  685.3833  695.0769  667.1485
# 2   71.6979   86.9203    ...     682.2323  685.9861  695.6796  667.7513
# 3   50.6703   65.8927    ...     681.4226  685.1765  694.8701  666.9417
# 4   33.2293   53.9901    ...     663.9816  667.7355  677.4291  649.5007
#
#        2412      2413      2414      2415      2416      2417
# 0  667.6788  665.5775  662.0291  665.9655  673.2073  681.4235
# 1  665.4311  663.3298  659.7815  663.7178  670.9596  679.1758
# 2  666.0339  663.9326  660.3843  664.3206  671.5623  679.7786
# 3  665.2243  663.1230  659.5746  663.5110  670.7528  678.9690
# 4  647.7833  645.6820  642.1336  646.0700  653.3118  661.5280
#
# [5 rows x 2419 columns]

# %% [markdown]
# ## Sample Submission

# %%
df_sample = pd.read_csv("../../data/sample_submission.csv")
df_sample.head()
# Out:
#        year       data_type  source_index  destination_index  value
# 0  20182019  depot_location          1256                NaN    NaN
# 1  20182019  depot_location          1595                NaN    NaN
# 2  20182019  depot_location          1271                NaN    NaN
# 3  20182019  depot_location          2001                NaN    NaN
# 4  20182019  depot_location          2201                NaN    NaN

# %%
df_sample.data_type.value_counts()
# Out:
# biomass_demand_supply    21646
# biomass_forecast          4836
# pellet_demand_supply       152
# depot_location              21
# refinery_location            4
# Name: data_type, dtype: int64

# %%
df_sample[df_sample.data_type == 'depot_location']
# Out:
#         year       data_type  source_index  destination_index  value
# 0   20182019  depot_location          1256                NaN    NaN
# 1   20182019  depot_location          1595                NaN    NaN
# 2   20182019  depot_location          1271                NaN    NaN
# 3   20182019  depot_location          2001                NaN    NaN
# 4   20182019  depot_location          2201                NaN    NaN
# 5   20182019  depot_location          1179                NaN    NaN
# 6   20182019  depot_location          1801                NaN    NaN
# 7   20182019  depot_location          1432                NaN    NaN
# 8   20182019  depot_location          1488                NaN    NaN
# 9   20182019  depot_location          2088                NaN    NaN
# 10  20182019  depot_location           308                NaN    NaN
# 11  20182019  depot_location           369                NaN    NaN
# 12  20182019  depot_location            98                NaN    NaN
# 13  20182019  depot_location          1867                NaN    NaN
# 14  20182019  depot_location          1775                NaN    NaN
# 15  20182019  depot_location          1947                NaN    NaN
# 16  20182019  depot_location          2252                NaN    NaN
# 17  20182019  depot_location          1808                NaN    NaN
# 18  20182019  depot_location          1322                NaN    NaN
# 19  20182019  depot_location          1791                NaN    NaN
# 20  20182019  depot_location           494                NaN    NaN

# %%
df_sample[df_sample.data_type == 'biomass_forecast']
# Out:
#        year         data_type  source_index  destination_index       value
# 25     2018  biomass_forecast             0                NaN    5.180296
# 26     2018  biomass_forecast             1                NaN   42.126946
# 27     2018  biomass_forecast             2                NaN   73.203232
# 28     2018  biomass_forecast             3                NaN  101.067352
# 29     2018  biomass_forecast             4                NaN   26.086885
# 30     2018  biomass_forecast             5                NaN   41.749001
# 31     2018  biomass_forecast             6                NaN   55.003929
# 32     2018  biomass_forecast             7                NaN   29.411613
# 33     2018  biomass_forecast             8                NaN   37.497009
# 34     2018  biomass_forecast             9                NaN   52.549976
# 35     2018  biomass_forecast            10                NaN    9.861409
# 36     2018  biomass_forecast            11                NaN    7.909709
# 37     2018  biomass_forecast            12                NaN    7.005911
# 38     2018  biomass_forecast            13                NaN    0.177587
# 39     2018  biomass_forecast            14                NaN    0.952279
# 40     2018  biomass_forecast            15                NaN   26.509066
# 41     2018  biomass_forecast            16                NaN   85.237656
# 42     2018  biomass_forecast            17                NaN  153.976090
# 43     2018  biomass_forecast            18                NaN  167.433884
# 44     2018  biomass_forecast            19                NaN   89.419334
# 45     2018  biomass_forecast            20                NaN  127.060349
# 46     2018  biomass_forecast            21                NaN  126.283836
# 47     2018  biomass_forecast            22                NaN  101.823853
# 48     2018  biomass_forecast            23                NaN  111.148941
# 49     2018  biomass_forecast            24                NaN  111.816162
# 50     2018  biomass_forecast            25                NaN   86.271019
# 51     2018  biomass_forecast            26                NaN   44.648521
# 52     2018  biomass_forecast            27                NaN   41.319397
# 53     2018  biomass_forecast            28                NaN    4.003597
# 54     2018  biomass_forecast            29                NaN    0.241195
# ...     ...               ...           ...                ...         ...
# 15730  2019  biomass_forecast          2388                NaN    0.438624
# 15731  2019  biomass_forecast          2389                NaN    0.273879
# 15732  2019  biomass_forecast          2390                NaN   42.956921
# 15733  2019  biomass_forecast          2391                NaN   43.761078
# 15734  2019  biomass_forecast          2392                NaN   15.109631
# 15735  2019  biomass_forecast          2393                NaN   55.307621
# 15736  2019  biomass_forecast          2394                NaN   26.056862
# 15737  2019  biomass_forecast          2395                NaN    5.133216
# 15738  2019  biomass_forecast          2396                NaN   22.289513
# 15739  2019  biomass_forecast          2397                NaN   35.423283
# 15740  2019  biomass_forecast          2398                NaN    4.257998
# 15741  2019  biomass_forecast          2399                NaN    0.055061
# 15742  2019  biomass_forecast          2400                NaN    1.108535
# 15743  2019  biomass_forecast          2401                NaN   44.317364
# 15744  2019  biomass_forecast          2402                NaN   47.830803
# 15745  2019  biomass_forecast          2403                NaN   23.679600
# 15746  2019  biomass_forecast          2404                NaN    2.984985
# 15747  2019  biomass_forecast          2405                NaN    5.500144
# 15748  2019  biomass_forecast          2406                NaN    0.932969
# 15749  2019  biomass_forecast          2407                NaN    8.196713
# 15750  2019  biomass_forecast          2408                NaN    9.644080
# 15751  2019  biomass_forecast          2409                NaN    3.543241
# 15752  2019  biomass_forecast          2410                NaN    0.050666
# 15753  2019  biomass_forecast          2411                NaN    0.057442
# 15754  2019  biomass_forecast          2412                NaN   13.510995
# 15755  2019  biomass_forecast          2413                NaN    5.321604
# 15756  2019  biomass_forecast          2414                NaN    0.120626
# 15757  2019  biomass_forecast          2415                NaN    0.038879
# 15758  2019  biomass_forecast          2416                NaN    1.304297
# 15759  2019  biomass_forecast          2417                NaN    0.226953
#
# [4836 rows x 5 columns]

# %%
df_sample[df_sample.data_type == 'pellet_demand_supply']
# Out:
#        year             data_type  source_index  destination_index  \
# 13266  2018  pellet_demand_supply          1256             1465.0
# 13267  2018  pellet_demand_supply          1256             1692.0
# 13268  2018  pellet_demand_supply          1256             1535.0
# 13269  2018  pellet_demand_supply          1256             1461.0
# 13270  2018  pellet_demand_supply          1595             1465.0
# 13271  2018  pellet_demand_supply          1595             1692.0
# 13272  2018  pellet_demand_supply          1595             1461.0
# 13273  2018  pellet_demand_supply          1271             1692.0
# 13274  2018  pellet_demand_supply          1271             1535.0
# 13275  2018  pellet_demand_supply          2001             1465.0
# 13276  2018  pellet_demand_supply          2001             1692.0
# 13277  2018  pellet_demand_supply          2001             1535.0
# 13278  2018  pellet_demand_supply          2001             1461.0
# 13279  2018  pellet_demand_supply          2201             1465.0
# 13280  2018  pellet_demand_supply          2201             1692.0
# 13281  2018  pellet_demand_supply          2201             1535.0
# 13282  2018  pellet_demand_supply          2201             1461.0
# 13283  2018  pellet_demand_supply          1179             1465.0
# 13284  2018  pellet_demand_supply          1179             1692.0
# 13285  2018  pellet_demand_supply          1179             1535.0
# 13286  2018  pellet_demand_supply          1179             1461.0
# 13287  2018  pellet_demand_supply          1801             1465.0
# 13288  2018  pellet_demand_supply          1801             1535.0
# 13289  2018  pellet_demand_supply          1432             1465.0
# 13290  2018  pellet_demand_supply          1432             1692.0
# 13291  2018  pellet_demand_supply          1432             1535.0
# 13292  2018  pellet_demand_supply          1432             1461.0
# 13293  2018  pellet_demand_supply          1488             1465.0
# 13294  2018  pellet_demand_supply          1488             1692.0
# 13295  2018  pellet_demand_supply          1488             1535.0
# ...     ...                   ...           ...                ...
# 26629  2019  pellet_demand_supply            98             1461.0
# 26630  2019  pellet_demand_supply          1867             1465.0
# 26631  2019  pellet_demand_supply          1867             1692.0
# 26632  2019  pellet_demand_supply          1867             1535.0
# 26633  2019  pellet_demand_supply          1867             1461.0
# 26634  2019  pellet_demand_supply          1775             1465.0
# 26635  2019  pellet_demand_supply          1775             1692.0
# 26636  2019  pellet_demand_supply          1775             1535.0
# 26637  2019  pellet_demand_supply          1775             1461.0
# 26638  2019  pellet_demand_supply          1947             1465.0
# 26639  2019  pellet_demand_supply          1947             1692.0
# 26640  2019  pellet_demand_supply          1947             1535.0
# 26641  2019  pellet_demand_supply          1947             1461.0
# 26642  2019  pellet_demand_supply          2252             1465.0
# 26643  2019  pellet_demand_supply          2252             1692.0
# 26644  2019  pellet_demand_supply          2252             1535.0
# 26645  2019  pellet_demand_supply          2252             1461.0
# 26646  2019  pellet_demand_supply          1808             1692.0
# 26647  2019  pellet_demand_supply          1808             1535.0
# 26648  2019  pellet_demand_supply          1322             1465.0
# 26649  2019  pellet_demand_supply          1322             1692.0
# 26650  2019  pellet_demand_supply          1322             1535.0
# 26651  2019  pellet_demand_supply          1322             1461.0
# 26652  2019  pellet_demand_supply          1791             1465.0
# 26653  2019  pellet_demand_supply          1791             1692.0
# 26654  2019  pellet_demand_supply          1791             1461.0
# 26655  2019  pellet_demand_supply           494             1465.0
# 26656  2019  pellet_demand_supply           494             1692.0
# 26657  2019  pellet_demand_supply           494             1535.0
# 26658  2019  pellet_demand_supply           494             1461.0
#
#               value
# 13266  4.473232e-01
# 13267  3.646738e+01
# 13268  1.184648e+04
# 13269  5.170925e+03
# 13270  4.608941e+03
# 13271  5.033927e-05
# 13272  1.314331e+04
# 13273  1.257224e+04
# 13274  5.722201e+03
# 13275  6.437653e+03
# 13276  5.584429e+03
# 13277  2.807305e+00
# 13278  3.714951e+03
# 13279  3.456958e+02
# 13280  1.511044e+04
# 13281  3.002272e+02
# 13282  2.599086e+00
# 13283  1.460099e+04
# 13284  1.190756e+03
# 13285  4.800292e+02
# 13286  3.661385e+02
# 13287  9.547010e+03
# 13288  7.585515e+03
# 13289  6.458800e+02
# 13290  1.972273e+03
# 13291  8.396241e+03
# 13292  4.795800e+03
# 13293  1.523264e+03
# 13294  2.587737e+03
# 13295  2.119727e+03
# ...             ...
# 26629  4.583387e+03
# 26630  1.673324e+04
# 26631  1.993838e+02
# 26632  1.109419e+01
# 26633  1.522630e-01
# 26634  5.793973e+03
# 26635  2.467299e+03
# 26636  4.415234e+03
# 26637  2.613417e+03
# 26638  1.842817e+03
# 26639  1.583562e+03
# 26640  7.718051e+03
# 26641  3.770142e+03
# 26642  1.028924e+04
# 26643  2.242200e+02
# 26644  3.641416e+03
# 26645  1.973667e+03
# 26646  2.768667e+03
# 26647  1.468540e+04
# 26648  3.514386e+02
# 26649  1.350691e-07
# 26650  1.815503e-01
# 26651  1.658747e+04
# 26652  2.700037e-03
# 26653  6.690522e+03
# 26654  9.441861e+03
# 26655  3.283043e+03
# 26656  5.161344e+03
# 26657  8.701711e+03
# 26658  5.623453e+01
#
# [152 rows x 5 columns]
