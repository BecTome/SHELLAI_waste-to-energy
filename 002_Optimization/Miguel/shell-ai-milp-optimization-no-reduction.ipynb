# %% [markdown]
# This is a **private notebook** to solve the optimization part in the **Shell.ai Hackathon 2023**. **Important, do not publish this notebook or its results anywhere, for private use only**.

# %% [markdown]
# # 1. Data loading

# %%
# !pip3 install mip
# Out:
# Collecting mip
#   Downloading mip-1.15.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 55.2 MB/s eta 0:00:00
# Requirement already satisfied: cffi==1.15.* in /opt/conda/lib/python3.10/site-packages (from mip) (1.15.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi==1.15.*->mip) (2.21)
# Installing collected packages: mip
# Successfully installed mip-1.15.0

# %%
# # Imports
# import pandas as pd
# import geopandas as gpd
# from datetime import date, timedelta
# import folium
# import folium.plugins
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np
# import plotly.express as px
# from branca.colormap import linear

# # GUJARAT center coordinates 22.6708° N, 71.5724° E
# GUJARAT_CENTER_LAT = 22.6708
# GUJARAT_CENTER_LON = 71.5724

# %%
# # Load csv data
# sample_submission_df = pd.read_csv('/kaggle/input/shellai/sample_submission.csv')
# sample_submission_df

# %%
# biomass_2018_forecast = sample_submission_df[(sample_submission_df['data_type'] == 'biomass_forecast')
#                                               & (sample_submission_df['year'] == 2018)]
# biomass_2018_forecast

# %%
# distance_matrix_df = pd.read_csv('/kaggle/input/shellai/Distance_Matrix.csv')
# distance_matrix = distance_matrix_df.to_numpy()[:, 1:] # Delete the first index row
# # distance_matrix[i, j] is the distance to move from source i to destination j
# distance_matrix_df

# %%
# print('Shape of distance matrix: ', distance_matrix.shape)
# print('Distance from source 0 to destination 2417: ', distance_matrix[0,2417])
# print('Distance from source 2417 to destination 0: ', distance_matrix[2417,0])

# %%
import pandas as pd
import os
from mip import Model, xsum, minimize, OptimizationStatus, BINARY
import matplotlib.pyplot as plt

SYNTH_DATA_PATH = '/kaggle/input/optimizationdata'     
OUT_SYNTH_DATA_PATH = '/kaggle/working'
FORECAST_FILE = 'Biomass_History_Synthetic.csv'
DISTANCE_FILE = 'Distance_Matrix_Synthetic.csv'

d_matrix = pd.read_csv(os.path.join(SYNTH_DATA_PATH, DISTANCE_FILE), 
                       index_col=0)
d_matrix = d_matrix.values

N = 30 #2418   # Use 30 for a small problem (optimal solution: to be computed)
TRANSPORT_FACTOR_A = 0.001
d_matrix_cost = TRANSPORT_FACTOR_A * d_matrix[:N, :N]

df_fc = pd.read_csv(os.path.join(SYNTH_DATA_PATH, FORECAST_FILE))
df_fc = df_fc.iloc[:N, :]

ls_j = range(len(d_matrix_cost))
year = 2018
cap_b_j = 20000 # Maximum depot capacity
cap_p_j = 100000 # Maximum production capacity
n_refineries = 5 # Number of refineries
n_depots = 25 # Number of depots

# Get the forecasted biomass for year 2018 of all the positions
d_bio_18 = df_fc.loc[:, '2018']
total_fc_18 = d_bio_18.sum()
d_bio_18 = d_bio_18.to_dict()
print("Forecasted biomass for year 2018: ", total_fc_18)


d_bio_19 = df_fc.loc[:, '2019']
total_fc_19 = d_bio_19.sum()
d_bio_19 = d_bio_19.to_dict()
print("Forecasted biomass for year 2019: ", total_fc_19)

# Get the solution for the optimization problem
m = Model(sense=minimize)
m.threads = -1

# Variables: biomass b_{i, 0}
# 1. All values (forecasted biomass, biomass demand-supply, pellet demand-supply) must be
# greater than or equal to zero.
b_18 = [m.add_var(name=f'b_2018_{i}_{j}', lb=0) for i in range(len(d_matrix_cost)) for j in ls_j]
print(f"Variables b_2018 go from {b_18[0].name} to {b_18[-1].name}")

b_19 = [m.add_var(name=f'b_2019_{i}_{j}', lb=0) for i in range(len(d_matrix_cost)) for j in ls_j]
print(f"Variables b_2019 go from {b_19[0].name} to {b_19[-1].name}")

p_18 = [m.add_var(name=f'p_2018_{i}_{j}', lb=0) for i in range(len(d_matrix_cost)) for j in ls_j]
print(f"Variables p_2018 go from {p_18[0].name} to {p_18[-1].name}")

p_19 = [m.add_var(name=f'p_2019_{i}_{j}', lb=0) for i in range(len(d_matrix_cost)) for j in ls_j]
print(f"Variables p_2019 go from {p_19[0].name} to {p_19[-1].name}")

x = [m.add_var(name=f'x_{j}', var_type=BINARY) for j in ls_j]
print(f"Variables x go from {x[0].name} to {x[-1].name}")

r = [m.add_var(name=f'r_{j}', var_type=BINARY) for j in ls_j]
print(f"Variables r go from {r[0].name} to {r[-1].name}")

# Constraints:
# 2. The amount of biomass procured for processing from each harvesting site ′𝑖𝑖′ must be less than
# or equal to that site’s forecasted biomass.
for i in range(len(d_matrix_cost)):
    m += xsum(m.var_by_name(f'b_2018_{i}_{j}') for j in ls_j) <= d_bio_18[i]
    m += xsum(m.var_by_name(f'b_2019_{i}_{j}') for j in ls_j) <= d_bio_19[i]

for j in ls_j:
    # 3-4. Can't transport more than storage limit
    m += xsum(m.var_by_name(f'b_2018_{i}_{j}') for i in range(len(d_matrix_cost))) <= cap_b_j * x[j]
    m += xsum(m.var_by_name(f'b_2019_{i}_{j}') for i in range(len(d_matrix_cost))) <= cap_b_j * x[j]
    m += xsum(m.var_by_name(f'p_2018_{i}_{j}') for i in range(len(d_matrix_cost))) <= cap_p_j * r[j]
    m += xsum(m.var_by_name(f'p_2019_{i}_{j}') for i in range(len(d_matrix_cost))) <= cap_p_j * r[j]

    # 8. Total amount of biomass entering each preprocessing depot is equal to the total amount of
    # pellets exiting that depot (within tolerance limit of 1e-03
    
    m += xsum(m.var_by_name(f'b_2018_{i}_{j}')  - m.var_by_name(f'p_2018_{j}_{i}') for i in range(len(d_matrix_cost))) <=\
          .001 * x[j]
    m += xsum(m.var_by_name(f'p_2018_{j}_{i}') - m.var_by_name(f'b_2018_{i}_{j}') for i in range(len(d_matrix_cost))) <=\
          .001 * x[j]
    
    m += xsum(m.var_by_name(f'b_2019_{i}_{j}')  - m.var_by_name(f'p_2019_{j}_{i}') for i in range(len(d_matrix_cost))) <=\
          .001 * x[j]
    m += xsum(m.var_by_name(f'p_2019_{j}_{i}') - m.var_by_name(f'b_2019_{i}_{j}') for i in range(len(d_matrix_cost))) <=\
          .001 * x[j]
    
# 5. Number of depots should be less than or equal to 25.
m += xsum(x[j] for j in ls_j) <= n_depots

# 6. Number of refineries should be less than or equal to 5.
m += xsum(r[j] for j in ls_j) <= n_refineries

# 7. At least 80% of the total forecasted biomass must be processed by refineries each year
m += xsum(m.var_by_name(f'p_2018_{i}_{j}') for i in range(len(d_matrix_cost)) for j in ls_j)\
    >= 0.8 * total_fc_18
m += xsum(m.var_by_name(f'p_2019_{i}_{j}') for i in range(len(d_matrix_cost)) for j in ls_j)\
    >= 0.8 * total_fc_19

# Previous optimization function used
# m.objective = minimize(xsum(d_matrix_cost[i, j] * (
#                                               m.var_by_name(f'b_2018_{i}_{j}') + m.var_by_name(f'b_2019_{i}_{j}') + \
#                                               m.var_by_name(f'p_2018_{i}_{j}') + m.var_by_name(f'p_2019_{i}_{j}')\
#                                               ) + \
#                             2*cap_b_j*x[j] - m.var_by_name(f'b_2018_{i}_{j}') - m.var_by_name(f'b_2019_{i}_{j}') + \
#                             2*cap_p_j*r[j] - m.var_by_name(f'p_2018_{i}_{j}') - m.var_by_name(f'p_2019_{i}_{j}') \
#                                 for i in range(len(d_matrix_cost)) for j in ls_j))
m.objective = minimize(xsum(d_matrix_cost[i, j] * (m.var_by_name(f'b_2018_{i}_{j}') + m.var_by_name(f'b_2019_{i}_{j}')) \
                            for i in range(len(d_matrix_cost)) for j in ls_j) + \
                       xsum(d_matrix_cost[i, j] * (m.var_by_name(f'p_2018_{i}_{j}') + m.var_by_name(f'p_2019_{i}_{j}')) \
                            for i in ls_j for j in ls_j) + \
                       xsum(2*cap_b_j*x[j] + 2*cap_p_j*r[j] for j in ls_j) + \
                       xsum(- m.var_by_name(f'b_2018_{i}_{j}') - m.var_by_name(f'b_2019_{i}_{j}') \
                            for i in range(len(d_matrix_cost)) for j in ls_j) + \
                       xsum(- m.var_by_name(f'p_2018_{i}_{j}') - m.var_by_name(f'p_2019_{i}_{j}') \
                            for i in ls_j for j in ls_j) \
                      )
# Out:
# Forecasted biomass for year 2018:  1488.016473495
# Forecasted biomass for year 2019:  1766.976034022
# Variables b_2018 go from b_2018_0_0 to b_2018_29_29
# Variables b_2019 go from b_2019_0_0 to b_2019_29_29
# Variables p_2018 go from p_2018_0_0 to p_2018_29_29
# Variables p_2019 go from p_2019_0_0 to p_2019_29_29
# Variables x go from x_0 to x_29
# Variables r go from r_0 to r_29

# %%
print('Number of constraints: ', m.num_rows)                  # number of rows (constraints) in the model
print('Number of variables: ', m.num_cols)                    # number of columns (variables) in the model
print('Number of integer variables: ', m.num_int)             # number of integer variables in the model
print('Number of non-zeros in constraint matrix: ', m.num_nz) # number of non-zeros in the constraint matrix
# Out:
# Number of constraints:  304
# Number of variables:  3660
# Number of integer variables:  60
# Number of non-zeros in constraint matrix:  14700

# %%
print("Solve")
# Solve the problem
# m.max_gap = 0.1
# m.threads = -1

status = m.optimize()  # max_seconds=100

print(status)
# Check the status and show the solutions
if status == OptimizationStatus.OPTIMAL:
    print('optimal solution cost {} found'.format(m.objective_value))
elif status == OptimizationStatus.FEASIBLE:
    print('sol.cost {} found, best possible: {}'.format(m.objective_value, m.objective_bound))
elif status in [OptimizationStatus.NO_SOLUTION_FOUND, OptimizationStatus.INFEASIBLE]:
    print('no feasible solution found, lower bound is: {}'.format(m.objective_bound))
if status == OptimizationStatus.OPTIMAL or status == OptimizationStatus.FEASIBLE:
    # print('solution:')
    d_sol = {}
    for v in m.vars:
        d_sol.update({v.name: v.x})
    # print("Solution: ", d_sol)
    df_sol = pd.DataFrame.from_dict(d_sol, orient='index', columns=['biomass'])
    df_sol.to_csv(os.path.join(OUT_SYNTH_DATA_PATH, 'solution.csv'))
# Out:
# Solve
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 24 2021
#
# Starting solution of the Linear programming relaxation problem using Dual Simplex
#
# Coin0506I Presolve 304 (0) rows, 3660 (0) columns and 14700 (0) elements
# Clp0014I Perturbing problem by 0.001% of 20916.457 - largest nonzero change 0.018922632 ( 0.17406027%) - largest zero change 0
# Clp0000I Optimal - objective value -0.00019404254
# Clp0032I Optimal objective -0.0001940425357 - 379 iterations time 0.022
# Clp1000I Unscaled problem has primal infeasibilities
#
# Starting MIP optimization
# Cgl0004I processed model has 304 rows, 3660 columns (60 integer (60 of which binary)) and 14700 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 0.105638
# Cbc0038I Initial state - 48 integers unsatisfied sum - 0.826666
# Cbc0038I Pass   1: suminf.    0.22667 (2) obj. 32237.4 iterations 200
# Cbc0038I Pass   2: suminf.    0.02667 (1) obj. 40237.4 iterations 1
# Cbc0038I Solution found of 234904
# Cbc0038I Relaxing continuous gives 233621
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 3458 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.19 seconds)
# Cbc0038I Round again with cutoff of 213472
# Cbc0038I Pass   3: suminf.    0.22667 (2) obj. 32237.4 iterations 0
# Cbc0038I Pass   4: suminf.    0.02667 (1) obj. 40237.4 iterations 1
# Cbc0038I Pass   5: suminf.    0.10075 (1) obj. 213472 iterations 110
# Cbc0038I Pass   6: suminf.    0.09892 (1) obj. 213472 iterations 149
# Cbc0038I Pass   7: suminf.    0.02667 (2) obj. 200198 iterations 80
# Cbc0038I Pass   8: suminf.    0.09952 (2) obj. 213472 iterations 108
# Cbc0038I Pass   9: suminf.    0.36327 (3) obj. 213472 iterations 360
# Cbc0038I Pass  10: suminf.    0.02667 (1) obj. 200308 iterations 100
# Cbc0038I Pass  11: suminf.    0.09894 (1) obj. 213472 iterations 132
# Cbc0038I Pass  12: suminf.    0.36304 (5) obj. 213472 iterations 219
# Cbc0038I Pass  13: suminf.    0.02667 (4) obj. 200239 iterations 92
# Cbc0038I Pass  14: suminf.    0.09925 (3) obj. 213472 iterations 96
# Cbc0038I Pass  15: suminf.    0.36198 (3) obj. 213472 iterations 289
# Cbc0038I Pass  16: suminf.    0.02667 (3) obj. 200217 iterations 79
# Cbc0038I Pass  17: suminf.    0.09935 (3) obj. 213472 iterations 92
# Cbc0038I Pass  18: suminf.    0.36303 (4) obj. 213472 iterations 266
# Cbc0038I Pass  19: suminf.    0.02667 (2) obj. 200286 iterations 85
# Cbc0038I Pass  20: suminf.    0.09919 (2) obj. 213472 iterations 139
# Cbc0038I Pass  21: suminf.    0.36322 (4) obj. 213472 iterations 278
# Cbc0038I Pass  22: suminf.    0.02667 (3) obj. 200323 iterations 104
# Cbc0038I Pass  23: suminf.    0.09899 (2) obj. 213472 iterations 150
# Cbc0038I Pass  24: suminf.    0.36160 (2) obj. 213472 iterations 277
# Cbc0038I Pass  25: suminf.    0.02667 (3) obj. 200309 iterations 97
# Cbc0038I Pass  26: suminf.    0.09928 (2) obj. 213472 iterations 145
# Cbc0038I Pass  27: suminf.    0.36419 (5) obj. 213472 iterations 270
# Cbc0038I Pass  28: suminf.    0.02667 (2) obj. 200303 iterations 73
# Cbc0038I Pass  29: suminf.    0.09900 (2) obj. 213472 iterations 109
# Cbc0038I Pass  30: suminf.    0.36185 (4) obj. 213472 iterations 357
# Cbc0038I Pass  31: suminf.    0.02667 (3) obj. 200410 iterations 97
# Cbc0038I Pass  32: suminf.    0.09902 (2) obj. 213472 iterations 172
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6 integers at bound fixed and 2958 continuous
# Cbc0038I Full problem 304 rows 3660 columns, reduced to 278 rows 696 columns
# Cbc0038I Mini branch and bound did not improve solution (1.92 seconds)
# Cbc0038I After 1.92 seconds - Feasibility pump exiting with objective of 233621 - took 1.73 seconds
# Cbc0012I Integer solution of 233621.19 found by feasibility pump after 0 iterations and 0 nodes (1.92 seconds)
# Cbc0038I Full problem 304 rows 3660 columns, reduced to 251 rows 2542 columns - 2 fixed gives 247, 2540 - still too large
# Cbc0038I Full problem 304 rows 3660 columns, reduced to 247 rows 2540 columns - too large
# Cbc0031I 639 added rows had average density of 35.336463
# Cbc0013I At root node, 639 cuts changed objective from 32125.326 to 67095.172 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 6985 row cuts average 2.0 elements, 0 column cuts (104 active)  in 0.131 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 26 row cuts average 4.6 elements, 0 column cuts (0 active)  in 0.240 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 3531 row cuts average 323.8 elements, 0 column cuts (0 active)  in 0.838 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 2 row cuts average 4.0 elements, 0 column cuts (0 active)  in 1.872 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 877 row cuts average 3.2 elements, 0 column cuts (0 active)  in 0.073 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 233621.19 best solution, best possible 67095.172 (43.09 seconds)
# Cbc0010I After 1 nodes, 2 on tree, 233621.19 best solution, best possible 67095.172 (44.40 seconds)
# Cbc0010I After 2 nodes, 2 on tree, 233621.19 best solution, best possible 67095.172 (45.19 seconds)
# Cbc0010I After 3 nodes, 1 on tree, 233621.19 best solution, best possible 67095.172 (45.91 seconds)
# Cbc0010I After 6 nodes, 2 on tree, 233621.19 best solution, best possible 67139.456 (47.46 seconds)
# Cbc0010I After 18 nodes, 3 on tree, 233621.19 best solution, best possible 70779.798 (48.23 seconds)
# Cbc0010I After 31 nodes, 6 on tree, 233621.19 best solution, best possible 70779.798 (48.94 seconds)
# Cbc0010I After 43 nodes, 4 on tree, 233621.19 best solution, best possible 71289.966 (49.69 seconds)
# Cbc0012I Integer solution of 233619.83 found by heuristic after 146248 iterations and 51 nodes (50.40 seconds)
# Cbc0010I After 52 nodes, 10 on tree, 233619.83 best solution, best possible 73087.546 (50.40 seconds)
# Cbc0010I After 67 nodes, 8 on tree, 233619.83 best solution, best possible 73087.546 (51.13 seconds)
# Cbc0010I After 88 nodes, 7 on tree, 233619.83 best solution, best possible 73087.546 (51.83 seconds)
# Cbc0010I After 106 nodes, 10 on tree, 233619.83 best solution, best possible 73087.546 (52.60 seconds)
# Cbc0010I After 117 nodes, 5 on tree, 233619.83 best solution, best possible 73087.546 (53.67 seconds)
# Cbc0010I After 123 nodes, 7 on tree, 233619.83 best solution, best possible 73087.546 (54.38 seconds)
# Cbc0010I After 134 nodes, 9 on tree, 233619.83 best solution, best possible 73087.546 (55.11 seconds)
# Cbc0012I Integer solution of 233607.49 found by heuristic after 194035 iterations and 140 nodes (55.53 seconds)
# Cbc0010I After 146 nodes, 9 on tree, 233607.49 best solution, best possible 73087.546 (55.83 seconds)
# Cbc0010I After 155 nodes, 8 on tree, 233607.49 best solution, best possible 73087.546 (56.54 seconds)
# Cbc0010I After 166 nodes, 8 on tree, 233607.49 best solution, best possible 73087.546 (57.29 seconds)
# Cbc0010I After 171 nodes, 12 on tree, 233607.49 best solution, best possible 73087.546 (58.08 seconds)
# Cbc0010I After 178 nodes, 13 on tree, 233607.49 best solution, best possible 73087.546 (58.94 seconds)
# Cbc0010I After 187 nodes, 13 on tree, 233607.49 best solution, best possible 73087.546 (59.67 seconds)
# Cbc0010I After 196 nodes, 16 on tree, 233607.49 best solution, best possible 73087.546 (60.45 seconds)
# Cbc0010I After 204 nodes, 15 on tree, 233607.49 best solution, best possible 73087.546 (61.21 seconds)
# Cbc0010I After 210 nodes, 17 on tree, 233607.49 best solution, best possible 73087.546 (62.01 seconds)
# Cbc0010I After 213 nodes, 19 on tree, 233607.49 best solution, best possible 73087.546 (62.73 seconds)
# Cbc0010I After 222 nodes, 20 on tree, 233607.49 best solution, best possible 73087.546 (63.46 seconds)
# Cbc0010I After 235 nodes, 22 on tree, 233607.49 best solution, best possible 73087.546 (64.23 seconds)
# Cbc0010I After 263 nodes, 27 on tree, 233607.49 best solution, best possible 73087.546 (64.97 seconds)
# Cbc0010I After 283 nodes, 24 on tree, 233607.49 best solution, best possible 73087.546 (65.70 seconds)
# Cbc0010I After 301 nodes, 25 on tree, 233607.49 best solution, best possible 73087.546 (66.45 seconds)
# Cbc0010I After 308 nodes, 26 on tree, 233607.49 best solution, best possible 73087.546 (67.17 seconds)
# Cbc0010I After 326 nodes, 24 on tree, 233607.49 best solution, best possible 73087.546 (67.87 seconds)
# Cbc0010I After 357 nodes, 22 on tree, 233607.49 best solution, best possible 73087.546 (68.63 seconds)
# Cbc0010I After 375 nodes, 28 on tree, 233607.49 best solution, best possible 73087.546 (69.40 seconds)
# Cbc0010I After 402 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (70.13 seconds)
# Cbc0010I After 418 nodes, 26 on tree, 233607.49 best solution, best possible 73087.546 (70.85 seconds)
# Cbc0010I After 434 nodes, 28 on tree, 233607.49 best solution, best possible 73087.546 (71.58 seconds)
# Cbc0010I After 456 nodes, 30 on tree, 233607.49 best solution, best possible 73087.546 (72.40 seconds)
# Cbc0010I After 462 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (73.13 seconds)
# Cbc0010I After 473 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (73.88 seconds)
# Cbc0010I After 485 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (74.73 seconds)
# Cbc0010I After 494 nodes, 37 on tree, 233607.49 best solution, best possible 73087.546 (75.44 seconds)
# Cbc0010I After 519 nodes, 41 on tree, 233607.49 best solution, best possible 73087.546 (76.16 seconds)
# Cbc0010I After 533 nodes, 39 on tree, 233607.49 best solution, best possible 73087.546 (76.94 seconds)
# Cbc0010I After 557 nodes, 45 on tree, 233607.49 best solution, best possible 73087.546 (77.64 seconds)
# Cbc0010I After 582 nodes, 48 on tree, 233607.49 best solution, best possible 73087.546 (78.37 seconds)
# Cbc0010I After 607 nodes, 51 on tree, 233607.49 best solution, best possible 73087.546 (79.19 seconds)
# Cbc0010I After 629 nodes, 57 on tree, 233607.49 best solution, best possible 73087.546 (79.92 seconds)
# Cbc0010I After 689 nodes, 47 on tree, 233607.49 best solution, best possible 73087.546 (80.63 seconds)
# Cbc0010I After 698 nodes, 52 on tree, 233607.49 best solution, best possible 73087.546 (81.35 seconds)
# Cbc0010I After 707 nodes, 54 on tree, 233607.49 best solution, best possible 73087.546 (82.09 seconds)
# Cbc0010I After 734 nodes, 53 on tree, 233607.49 best solution, best possible 73087.546 (82.81 seconds)
# Cbc0010I After 789 nodes, 55 on tree, 233607.49 best solution, best possible 73087.546 (83.51 seconds)
# Cbc0010I After 830 nodes, 53 on tree, 233607.49 best solution, best possible 73087.546 (84.24 seconds)
# Cbc0010I After 867 nodes, 54 on tree, 233607.49 best solution, best possible 73087.546 (84.96 seconds)
# Cbc0010I After 909 nodes, 50 on tree, 233607.49 best solution, best possible 73087.546 (85.73 seconds)
# Cbc0010I After 921 nodes, 49 on tree, 233607.49 best solution, best possible 73087.546 (86.43 seconds)
# Cbc0010I After 940 nodes, 49 on tree, 233607.49 best solution, best possible 73087.546 (87.17 seconds)
# Cbc0010I After 988 nodes, 48 on tree, 233607.49 best solution, best possible 73087.546 (87.92 seconds)
# Cbc0010I After 1018 nodes, 48 on tree, 233607.49 best solution, best possible 73087.546 (88.64 seconds)
# Cbc0010I After 1053 nodes, 44 on tree, 233607.49 best solution, best possible 73087.546 (89.40 seconds)
# Cbc0010I After 1070 nodes, 43 on tree, 233607.49 best solution, best possible 73087.546 (90.17 seconds)
# Cbc0010I After 1094 nodes, 43 on tree, 233607.49 best solution, best possible 73087.546 (90.95 seconds)
# Cbc0010I After 1116 nodes, 43 on tree, 233607.49 best solution, best possible 73087.546 (91.72 seconds)
# Cbc0010I After 1140 nodes, 39 on tree, 233607.49 best solution, best possible 73087.546 (92.49 seconds)
# Cbc0010I After 1190 nodes, 37 on tree, 233607.49 best solution, best possible 73087.546 (93.26 seconds)
# Cbc0010I After 1206 nodes, 37 on tree, 233607.49 best solution, best possible 73087.546 (94.03 seconds)
# Cbc0010I After 1225 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (94.77 seconds)
# Cbc0010I After 1240 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (95.62 seconds)
# Cbc0010I After 1246 nodes, 37 on tree, 233607.49 best solution, best possible 73087.546 (96.34 seconds)
# Cbc0010I After 1258 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (97.07 seconds)
# Cbc0010I After 1268 nodes, 37 on tree, 233607.49 best solution, best possible 73087.546 (97.83 seconds)
# Cbc0010I After 1275 nodes, 37 on tree, 233607.49 best solution, best possible 73087.546 (98.55 seconds)
# Cbc0010I After 1287 nodes, 41 on tree, 233607.49 best solution, best possible 73087.546 (99.45 seconds)
# Cbc0010I After 1302 nodes, 42 on tree, 233607.49 best solution, best possible 73087.546 (100.19 seconds)
# Cbc0010I After 1326 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (101.18 seconds)
# Cbc0010I After 1342 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (101.89 seconds)
# Cbc0010I After 1353 nodes, 31 on tree, 233607.49 best solution, best possible 73087.546 (103.03 seconds)
# Cbc0010I After 1358 nodes, 30 on tree, 233607.49 best solution, best possible 73087.546 (103.74 seconds)
# Cbc0010I After 1363 nodes, 32 on tree, 233607.49 best solution, best possible 73087.546 (104.49 seconds)
# Cbc0010I After 1368 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (105.23 seconds)
# Cbc0010I After 1375 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (105.95 seconds)
# Cbc0010I After 1384 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (106.69 seconds)
# Cbc0010I After 1397 nodes, 35 on tree, 233607.49 best solution, best possible 73087.546 (107.42 seconds)
# Cbc0010I After 1410 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (108.21 seconds)
# Cbc0010I After 1428 nodes, 29 on tree, 233607.49 best solution, best possible 73087.546 (109.17 seconds)
# Cbc0010I After 1435 nodes, 32 on tree, 233607.49 best solution, best possible 73087.546 (109.88 seconds)
# Cbc0010I After 1443 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (110.69 seconds)
# Cbc0010I After 1451 nodes, 39 on tree, 233607.49 best solution, best possible 73087.546 (111.50 seconds)
# Cbc0010I After 1465 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (112.23 seconds)
# Cbc0010I After 1478 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (112.98 seconds)
# Cbc0010I After 1487 nodes, 38 on tree, 233607.49 best solution, best possible 73087.546 (113.71 seconds)
# Cbc0010I After 1499 nodes, 40 on tree, 233607.49 best solution, best possible 73087.546 (114.41 seconds)
# Cbc0010I After 1513 nodes, 38 on tree, 233607.49 best solution, best possible 73087.546 (115.12 seconds)
# Cbc0010I After 1524 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (115.91 seconds)
# Cbc0010I After 1540 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (116.76 seconds)
# Cbc0010I After 1551 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (117.60 seconds)
# Cbc0010I After 1568 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (118.36 seconds)
# Cbc0010I After 1585 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (119.07 seconds)
# Cbc0010I After 1604 nodes, 35 on tree, 233607.49 best solution, best possible 73087.546 (119.86 seconds)
# Cbc0010I After 1617 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (120.58 seconds)
# Cbc0010I After 1630 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (121.34 seconds)
# Cbc0010I After 1642 nodes, 37 on tree, 233607.49 best solution, best possible 73087.546 (122.19 seconds)
# Cbc0010I After 1659 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (122.93 seconds)
# Cbc0010I After 1675 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (123.68 seconds)
# Cbc0010I After 1694 nodes, 32 on tree, 233607.49 best solution, best possible 73087.546 (124.52 seconds)
# Cbc0010I After 1716 nodes, 31 on tree, 233607.49 best solution, best possible 73087.546 (125.25 seconds)
# Cbc0010I After 1730 nodes, 30 on tree, 233607.49 best solution, best possible 73087.546 (125.96 seconds)
# Cbc0010I After 1741 nodes, 31 on tree, 233607.49 best solution, best possible 73087.546 (126.73 seconds)
# Cbc0010I After 1751 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (127.49 seconds)
# Cbc0010I After 1760 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (128.24 seconds)
# Cbc0010I After 1770 nodes, 35 on tree, 233607.49 best solution, best possible 73087.546 (129.00 seconds)
# Cbc0010I After 1781 nodes, 38 on tree, 233607.49 best solution, best possible 73087.546 (129.76 seconds)
# Cbc0010I After 1792 nodes, 39 on tree, 233607.49 best solution, best possible 73087.546 (130.47 seconds)
# Cbc0010I After 1808 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (131.17 seconds)
# Cbc0010I After 1823 nodes, 38 on tree, 233607.49 best solution, best possible 73087.546 (131.90 seconds)
# Cbc0010I After 1834 nodes, 35 on tree, 233607.49 best solution, best possible 73087.546 (132.64 seconds)
# Cbc0010I After 1847 nodes, 36 on tree, 233607.49 best solution, best possible 73087.546 (133.40 seconds)
# Cbc0010I After 1857 nodes, 34 on tree, 233607.49 best solution, best possible 73087.546 (134.15 seconds)
# Cbc0010I After 1868 nodes, 33 on tree, 233607.49 best solution, best possible 73087.546 (134.87 seconds)
# Cbc0010I After 1880 nodes, 32 on tree, 233607.49 best solution, best possible 73087.546 (135.57 seconds)
# Cbc0010I After 1898 nodes, 28 on tree, 233607.49 best solution, best possible 73087.546 (136.39 seconds)
# Cbc0010I After 1907 nodes, 30 on tree, 233607.49 best solution, best possible 73087.546 (137.26 seconds)
# Cbc0010I After 1921 nodes, 30 on tree, 233607.49 best solution, best possible 73087.546 (137.98 seconds)
# Cbc0010I After 1930 nodes, 29 on tree, 233607.49 best solution, best possible 73087.546 (138.71 seconds)
# Cbc0010I After 1945 nodes, 30 on tree, 233607.49 best solution, best possible 73087.546 (139.48 seconds)
# Cbc0010I After 1963 nodes, 26 on tree, 233607.49 best solution, best possible 73087.546 (140.30 seconds)
# Cbc0010I After 1980 nodes, 26 on tree, 233607.49 best solution, best possible 73087.546 (141.02 seconds)
# Cbc0010I After 1993 nodes, 24 on tree, 233607.49 best solution, best possible 73087.546 (141.72 seconds)
# Cbc0010I After 2006 nodes, 24 on tree, 233607.49 best solution, best possible 73087.546 (142.51 seconds)
# Cbc0010I After 2014 nodes, 28 on tree, 233607.49 best solution, best possible 73087.546 (143.35 seconds)
# Cbc0010I After 2022 nodes, 31 on tree, 233607.49 best solution, best possible 73087.546 (144.08 seconds)
# Cbc0010I After 2036 nodes, 28 on tree, 233607.49 best solution, best possible 73087.546 (144.80 seconds)
# Cbc0010I After 2053 nodes, 26 on tree, 233607.49 best solution, best possible 73087.546 (145.51 seconds)
# Cbc0010I After 2072 nodes, 23 on tree, 233607.49 best solution, best possible 73087.546 (146.23 seconds)
# Cbc0010I After 2084 nodes, 25 on tree, 233607.49 best solution, best possible 73087.546 (146.99 seconds)
# Cbc0010I After 2097 nodes, 27 on tree, 233607.49 best solution, best possible 73087.546 (147.70 seconds)
# Cbc0010I After 2115 nodes, 22 on tree, 233607.49 best solution, best possible 73087.546 (148.46 seconds)
# Cbc0010I After 2128 nodes, 25 on tree, 233607.49 best solution, best possible 73087.546 (149.18 seconds)
# Cbc0010I After 2142 nodes, 24 on tree, 233607.49 best solution, best possible 73087.546 (149.89 seconds)
# Cbc0010I After 2159 nodes, 21 on tree, 233607.49 best solution, best possible 73087.546 (150.64 seconds)
# Cbc0010I After 2173 nodes, 19 on tree, 233607.49 best solution, best possible 73087.546 (151.35 seconds)
# Cbc0010I After 2183 nodes, 18 on tree, 233607.49 best solution, best possible 73087.546 (152.06 seconds)
# Cbc0010I After 2199 nodes, 16 on tree, 233607.49 best solution, best possible 73087.546 (152.88 seconds)
# Cbc0010I After 2211 nodes, 14 on tree, 233607.49 best solution, best possible 73087.546 (153.59 seconds)
# Cbc0010I After 2224 nodes, 14 on tree, 233607.49 best solution, best possible 73087.546 (154.31 seconds)
# Cbc0010I After 2238 nodes, 10 on tree, 233607.49 best solution, best possible 73087.546 (155.04 seconds)
# Cbc0010I After 2249 nodes, 10 on tree, 233607.49 best solution, best possible 73087.546 (155.76 seconds)
# Cbc0010I After 2260 nodes, 7 on tree, 233607.49 best solution, best possible 73087.546 (156.49 seconds)
# Cbc0010I After 2269 nodes, 10 on tree, 233607.49 best solution, best possible 73087.546 (157.24 seconds)
# Cbc0010I After 2277 nodes, 13 on tree, 233607.49 best solution, best possible 73087.546 (157.98 seconds)
# Cbc0010I After 2294 nodes, 5 on tree, 233607.49 best solution, best possible 73087.546 (158.71 seconds)
# Cbc0010I After 2300 nodes, 7 on tree, 233607.49 best solution, best possible 73087.546 (159.70 seconds)
# Cbc0010I After 2307 nodes, 9 on tree, 233607.49 best solution, best possible 103114.7 (160.41 seconds)
# Cbc0010I After 2318 nodes, 3 on tree, 233607.49 best solution, best possible 103114.7 (161.13 seconds)
# Cbc0010I After 2322 nodes, 5 on tree, 233607.49 best solution, best possible 103114.7 (161.98 seconds)
# Cbc0010I After 2328 nodes, 7 on tree, 233607.49 best solution, best possible 103114.7 (163.30 seconds)
# Cbc0010I After 2332 nodes, 8 on tree, 233607.49 best solution, best possible 103114.7 (164.04 seconds)
# Cbc0010I After 2341 nodes, 11 on tree, 233607.49 best solution, best possible 103114.7 (164.94 seconds)
# Cbc0010I After 2349 nodes, 14 on tree, 233607.49 best solution, best possible 103114.7 (165.78 seconds)
# Cbc0010I After 2357 nodes, 14 on tree, 233607.49 best solution, best possible 103114.7 (166.53 seconds)
# Cbc0010I After 2364 nodes, 14 on tree, 233607.49 best solution, best possible 103114.7 (167.28 seconds)
# Cbc0010I After 2367 nodes, 17 on tree, 233607.49 best solution, best possible 103114.7 (168.00 seconds)
# Cbc0010I After 2376 nodes, 17 on tree, 233607.49 best solution, best possible 103114.7 (168.72 seconds)
# Cbc0010I After 2385 nodes, 17 on tree, 233607.49 best solution, best possible 103114.7 (169.46 seconds)
# Cbc0010I After 2396 nodes, 19 on tree, 233607.49 best solution, best possible 103114.7 (170.20 seconds)
# Cbc0010I After 2404 nodes, 19 on tree, 233607.49 best solution, best possible 103114.7 (171.01 seconds)
# Cbc0010I After 2412 nodes, 15 on tree, 233607.49 best solution, best possible 103114.7 (171.75 seconds)
# Cbc0010I After 2417 nodes, 16 on tree, 233607.49 best solution, best possible 103114.7 (172.67 seconds)
# Cbc0010I After 2424 nodes, 18 on tree, 233607.49 best solution, best possible 103114.7 (173.48 seconds)
# Cbc0010I After 2435 nodes, 20 on tree, 233607.49 best solution, best possible 103114.7 (174.18 seconds)
# Cbc0010I After 2448 nodes, 19 on tree, 233607.49 best solution, best possible 103114.7 (174.89 seconds)
# Cbc0010I After 2460 nodes, 18 on tree, 233607.49 best solution, best possible 103114.7 (175.60 seconds)
# Cbc0010I After 2469 nodes, 19 on tree, 233607.49 best solution, best possible 103114.7 (176.32 seconds)
# Cbc0010I After 2480 nodes, 20 on tree, 233607.49 best solution, best possible 103114.7 (177.10 seconds)
# Cbc0010I After 2491 nodes, 18 on tree, 233607.49 best solution, best possible 103114.7 (177.85 seconds)
# Cbc0010I After 2498 nodes, 21 on tree, 233607.49 best solution, best possible 103114.7 (178.62 seconds)
# Cbc0010I After 2507 nodes, 23 on tree, 233607.49 best solution, best possible 103114.7 (179.48 seconds)
# Cbc0010I After 2515 nodes, 24 on tree, 233607.49 best solution, best possible 103114.7 (180.27 seconds)
# Cbc0010I After 2526 nodes, 24 on tree, 233607.49 best solution, best possible 103114.7 (181.21 seconds)
# Cbc0010I After 2538 nodes, 21 on tree, 233607.49 best solution, best possible 103114.7 (181.96 seconds)
# Cbc0010I After 2543 nodes, 26 on tree, 233607.49 best solution, best possible 103114.7 (182.76 seconds)
# Cbc0010I After 2556 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (183.50 seconds)
# Cbc0010I After 2570 nodes, 25 on tree, 233607.49 best solution, best possible 103114.7 (184.23 seconds)
# Cbc0010I After 2580 nodes, 24 on tree, 233607.49 best solution, best possible 103114.7 (185.06 seconds)
# Cbc0010I After 2589 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (185.78 seconds)
# Cbc0010I After 2600 nodes, 24 on tree, 233607.49 best solution, best possible 103114.7 (186.54 seconds)
# Cbc0010I After 2610 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (187.39 seconds)
# Cbc0010I After 2623 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (188.39 seconds)
# Cbc0010I After 2637 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (189.12 seconds)
# Cbc0010I After 2648 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (189.83 seconds)
# Cbc0010I After 2661 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (190.60 seconds)
# Cbc0010I After 2671 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (191.32 seconds)
# Cbc0010I After 2684 nodes, 29 on tree, 233607.49 best solution, best possible 103114.7 (192.19 seconds)
# Cbc0010I After 2695 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (192.96 seconds)
# Cbc0010I After 2704 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (193.74 seconds)
# Cbc0010I After 2712 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (194.61 seconds)
# Cbc0010I After 2719 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (195.63 seconds)
# Cbc0010I After 2727 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (196.34 seconds)
# Cbc0010I After 2734 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (197.25 seconds)
# Cbc0010I After 2743 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (198.15 seconds)
# Cbc0010I After 2750 nodes, 29 on tree, 233607.49 best solution, best possible 103114.7 (199.08 seconds)
# Cbc0010I After 2758 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (199.86 seconds)
# Cbc0010I After 2765 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (200.60 seconds)
# Cbc0010I After 2773 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (201.38 seconds)
# Cbc0010I After 2779 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (202.25 seconds)
# Cbc0010I After 2788 nodes, 25 on tree, 233607.49 best solution, best possible 103114.7 (203.08 seconds)
# Cbc0010I After 2795 nodes, 26 on tree, 233607.49 best solution, best possible 103114.7 (203.80 seconds)
# Cbc0010I After 2802 nodes, 27 on tree, 233607.49 best solution, best possible 103114.7 (204.55 seconds)
# Cbc0010I After 2809 nodes, 29 on tree, 233607.49 best solution, best possible 103114.7 (205.34 seconds)
# Cbc0010I After 2821 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (206.08 seconds)
# Cbc0010I After 2827 nodes, 29 on tree, 233607.49 best solution, best possible 103114.7 (206.82 seconds)
# Cbc0010I After 2838 nodes, 29 on tree, 233607.49 best solution, best possible 103114.7 (207.58 seconds)
# Cbc0010I After 2851 nodes, 28 on tree, 233607.49 best solution, best possible 103114.7 (208.43 seconds)
# Cbc0010I After 2859 nodes, 29 on tree, 233607.49 best solution, best possible 103114.7 (209.13 seconds)
# Cbc0010I After 2871 nodes, 26 on tree, 233607.49 best solution, best possible 103114.7 (209.87 seconds)
# Cbc0010I After 2884 nodes, 24 on tree, 233607.49 best solution, best possible 103114.7 (210.58 seconds)
# Cbc0010I After 2894 nodes, 26 on tree, 233607.49 best solution, best possible 103114.7 (211.30 seconds)
# Cbc0010I After 2901 nodes, 25 on tree, 233607.49 best solution, best possible 103114.7 (212.01 seconds)
# Cbc0010I After 2911 nodes, 23 on tree, 233607.49 best solution, best possible 103114.7 (212.77 seconds)
# Cbc0010I After 2919 nodes, 25 on tree, 233607.49 best solution, best possible 103114.7 (213.51 seconds)
# Cbc0010I After 2927 nodes, 25 on tree, 233607.49 best solution, best possible 103114.7 (214.26 seconds)
# Cbc0010I After 2940 nodes, 23 on tree, 233607.49 best solution, best possible 103114.7 (214.97 seconds)
# Cbc0010I After 2954 nodes, 22 on tree, 233607.49 best solution, best possible 103114.7 (216.06 seconds)
# Cbc0010I After 2962 nodes, 22 on tree, 233607.49 best solution, best possible 103114.7 (216.92 seconds)
# Cbc0010I After 2969 nodes, 21 on tree, 233607.49 best solution, best possible 103114.7 (217.64 seconds)
# Cbc0010I After 2976 nodes, 23 on tree, 233607.49 best solution, best possible 103114.7 (218.35 seconds)
# Cbc0010I After 2986 nodes, 21 on tree, 233607.49 best solution, best possible 103114.7 (219.09 seconds)
# Cbc0010I After 2996 nodes, 18 on tree, 233607.49 best solution, best possible 103114.7 (219.82 seconds)
# Cbc0010I After 3003 nodes, 19 on tree, 233607.49 best solution, best possible 103114.7 (220.54 seconds)
# Cbc0010I After 3010 nodes, 19 on tree, 233607.49 best solution, best possible 103114.7 (221.30 seconds)
# Cbc0010I After 3018 nodes, 15 on tree, 233607.49 best solution, best possible 103114.7 (222.16 seconds)
# Cbc0010I After 3024 nodes, 17 on tree, 233607.49 best solution, best possible 103114.7 (222.93 seconds)
# Cbc0010I After 3031 nodes, 15 on tree, 233607.49 best solution, best possible 103114.7 (223.64 seconds)
# Cbc0010I After 3038 nodes, 14 on tree, 233607.49 best solution, best possible 103114.7 (224.44 seconds)
# Cbc0010I After 3046 nodes, 12 on tree, 233607.49 best solution, best possible 103114.7 (225.31 seconds)
# Cbc0010I After 3051 nodes, 13 on tree, 233607.49 best solution, best possible 103114.7 (226.17 seconds)
# Cbc0010I After 3055 nodes, 16 on tree, 233607.49 best solution, best possible 103114.7 (226.93 seconds)
# Cbc0010I After 3068 nodes, 10 on tree, 233607.49 best solution, best possible 103114.7 (227.82 seconds)
# Cbc0010I After 3079 nodes, 10 on tree, 233607.49 best solution, best possible 103114.7 (228.82 seconds)
# Cbc0010I After 3085 nodes, 12 on tree, 233607.49 best solution, best possible 103114.7 (229.68 seconds)
# Cbc0010I After 3095 nodes, 12 on tree, 233607.49 best solution, best possible 103114.7 (230.38 seconds)
# Cbc0010I After 3111 nodes, 7 on tree, 233607.49 best solution, best possible 103114.7 (231.45 seconds)
# Cbc0010I After 3125 nodes, 3 on tree, 233607.49 best solution, best possible 103114.7 (232.16 seconds)
# Cbc0010I After 3133 nodes, 2 on tree, 233607.49 best solution, best possible 155715.16 (233.02 seconds)
# Cbc0010I After 3139 nodes, 2 on tree, 233607.49 best solution, best possible 155715.16 (234.12 seconds)
# Cbc0010I After 3142 nodes, 2 on tree, 233607.49 best solution, best possible 155715.16 (234.83 seconds)
# Cbc0010I After 3148 nodes, 2 on tree, 233607.49 best solution, best possible 168917.54 (235.76 seconds)
# Cbc0010I After 3153 nodes, 2 on tree, 233607.49 best solution, best possible 174781.96 (236.84 seconds)
# Cbc0010I After 3157 nodes, 4 on tree, 233607.49 best solution, best possible 174846.19 (237.64 seconds)
# Cbc0010I After 3167 nodes, 6 on tree, 233607.49 best solution, best possible 181295.76 (238.36 seconds)
# Cbc0010I After 3179 nodes, 9 on tree, 233607.49 best solution, best possible 182094.9 (239.22 seconds)
# Cbc0010I After 3192 nodes, 7 on tree, 233607.49 best solution, best possible 183810.25 (240.00 seconds)
# Cbc0010I After 3199 nodes, 10 on tree, 233607.49 best solution, best possible 188655.97 (240.73 seconds)
# Cbc0010I After 3209 nodes, 6 on tree, 233607.49 best solution, best possible 188655.97 (241.47 seconds)
# Cbc0010I After 3215 nodes, 8 on tree, 233607.49 best solution, best possible 188655.97 (242.19 seconds)
# Cbc0010I After 3223 nodes, 8 on tree, 233607.49 best solution, best possible 188683.85 (242.95 seconds)
# Cbc0010I After 3231 nodes, 7 on tree, 233607.49 best solution, best possible 188713.56 (243.68 seconds)
# Cbc0010I After 3238 nodes, 10 on tree, 233607.49 best solution, best possible 188713.56 (244.39 seconds)
# Cbc0010I After 3246 nodes, 14 on tree, 233607.49 best solution, best possible 188765.23 (245.32 seconds)
# Cbc0010I After 3256 nodes, 15 on tree, 233607.49 best solution, best possible 199157.86 (246.02 seconds)
# Cbc0010I After 3271 nodes, 13 on tree, 233607.49 best solution, best possible 202590.45 (246.88 seconds)
# Cbc0010I After 3284 nodes, 11 on tree, 233607.49 best solution, best possible 205735.67 (247.59 seconds)
# Cbc0010I After 3297 nodes, 6 on tree, 233607.49 best solution, best possible 208462.31 (248.41 seconds)
# Cbc0010I After 3309 nodes, 7 on tree, 233607.49 best solution, best possible 217073.82 (249.11 seconds)
# Cbc0010I After 3322 nodes, 4 on tree, 233607.49 best solution, best possible 217366.06 (249.98 seconds)
# Cbc0010I After 3333 nodes, 2 on tree, 233607.49 best solution, best possible 217366.06 (250.82OptimizationStatus.OPTIMAL
# optimal solution cost 233607.49178295932 found

# %%
# Sanity check for all quantities
sent_biomass_to_depots_18 = df_sol.loc[df_sol.index.str.startswith('b_2018'), 'biomass'].sum()
sent_pellets_to_refinery_18 = df_sol.loc[df_sol.index.str.startswith('p_2018'), 'biomass'].sum()
print('Forecasted biomass for year 2018: ', total_fc_18)
print('Biomass transported to depots for year 2018: ', sent_biomass_to_depots_18)
print('Biomass transported to depots for year 2018: ', sent_pellets_to_refinery_18)
print()
sent_biomass_to_depots_19 = df_sol.loc[df_sol.index.str.startswith('b_2019'), 'biomass'].sum()
sent_pellets_to_refinery_19 = df_sol.loc[df_sol.index.str.startswith('p_2019'), 'biomass'].sum()
print("Forecasted biomass for year 2019: ", total_fc_19)
print('Biomass transported to depots for year 2019: ', sent_biomass_to_depots_19)
print('Biomass transported to depots for year 2019: ', sent_pellets_to_refinery_19)
# Out:
# Forecasted biomass for year 2018:  1488.016473495
# Biomass transported to depots for year 2018:  1488.016473495
# Biomass transported to depots for year 2018:  1488.0174734949999
#
# Forecasted biomass for year 2019:  1766.976034022
# Biomass transported to depots for year 2019:  1766.9760340219998
# Biomass transported to depots for year 2019:  1766.9770340219998

# %%
# underuse_cost = float(xsum(2*cap_b_j*x[j] + 2*cap_p_j*r[j] for j in ls_j)) + \
#                        float(xsum(- df_sol.loc[f'b_2018_{i}_{j}'][0] - df_sol.loc[f'b_2019_{i}_{j}'][0] \
#                             for i in range(len(d_matrix)) for j in ls_j)) + \
#                        float(xsum(- df_sol.loc[f'p_2018_{i}_{j}'][0] - df_sol.loc[f'p_2019_{i}_{j}'][0] \
#                             for i in ls_j for j in ls_j))
# print(underuse_cost)
